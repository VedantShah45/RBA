# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('rba-dataset.csv')

# %%
df
# Out:
#              index          Login Timestamp              User ID  \
# 0                0  2020-02-03 12:43:30.772 -4324475583306591935
# 1                1  2020-02-03 12:43:43.549 -4324475583306591935
# 2                2  2020-02-03 12:43:55.873 -3284137479262433373
# 3                3  2020-02-03 12:43:56.180 -4324475583306591935
# 4                4  2020-02-03 12:43:59.396 -4618854071942621186
# ...            ...                      ...                  ...
# 31269259  31269259  2021-02-28 23:59:47.766 -4324475583306591935
# 31269260  31269260  2021-02-28 23:59:49.956 -4324475583306591935
# 31269261  31269261  2021-02-28 23:59:54.233 -4324475583306591935
# 31269262  31269262  2021-02-28 23:59:56.343 -4324475583306591935
# 31269263  31269263  2021-02-28 23:59:58.756 -3863191272176615105
#
#           Round-Trip Time [ms]     IP Address Country          Region  \
# 0                          NaN    10.0.65.171      NO               -
# ...

# %%
df.dtypes
# Out:
# index                         int64
# Login Timestamp              object
# User ID                       int64
# Round-Trip Time [ms]        float64
# IP Address                   object
# Country                      object
# Region                       object
# City                         object
# ASN                           int64
# User Agent String            object
# Browser Name and Version     object
# OS Name and Version          object
# Device Type                  object
# Login Successful               bool
# Is Attack IP                   bool
# Is Account Takeover            bool
# dtype: object

# %%
df.describe(include='all')
# Out:
#                index          Login Timestamp       User ID  \
# count   3.126926e+07                 31269264  3.126926e+07
# unique           NaN                 31269085           NaN
# top              NaN  2020-10-31 16:22:56.302           NaN
# freq             NaN                        2           NaN
# mean    1.563463e+07                      NaN -1.924043e+18
# std     9.026659e+06                      NaN  4.514276e+18
# min     0.000000e+00                      NaN -9.223371e+18
# 25%     7.817316e+06                      NaN -4.324476e+18
# 50%     1.563463e+07                      NaN -4.324476e+18
# 75%     2.345195e+07                      NaN  9.119813e+17
# max     3.126926e+07                      NaN  9.223359e+18
#
#         Round-Trip Time [ms]    IP Address   Country    Region      City  \
# count           1.275935e+06      31269264  31269264  31221855  31260674
# unique                   NaN       3512330       229      2638     38885
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 31269264 entries, 0 to 31269263
# Data columns (total 16 columns):
#  #   Column                    Dtype
# ---  ------                    -----
#  0   index                     int64
#  1   Login Timestamp           object
#  2   User ID                   int64
#  3   Round-Trip Time [ms]      float64
#  4   IP Address                object
#  5   Country                   object
#  6   Region                    object
#  7   City                      object
#  8   ASN                       int64
#  9   User Agent String         object
#  10  Browser Name and Version  object
#  11  OS Name and Version       object
#  12  Device Type               object
#  13  Login Successful          bool
#  14  Is Attack IP              bool
#  15  Is Account Takeover       bool
# dtypes: bool(3), float64(1), int64(3), object(9)
# memory usage: 3.1+ GB

# %%
headers = list(df)
headers
# Out:
# ['index',
#  'Login Timestamp',
#  'User ID',
#  'Round-Trip Time [ms]',
#  'IP Address',
#  'Country',
#  'Region',
#  'City',
#  'ASN',
#  'User Agent String',
#  'Browser Name and Version',
#  'OS Name and Version',
#  'Device Type',
#  'Login Successful',
#  'Is Attack IP',
#  'Is Account Takeover']

# %%
df.isnull()
# Out:
#           index  Login Timestamp  User ID  Round-Trip Time [ms]  IP Address  \
# 0         False            False    False                  True       False
# 1         False            False    False                  True       False
# 2         False            False    False                  True       False
# 3         False            False    False                  True       False
# 4         False            False    False                  True       False
# ...         ...              ...      ...                   ...         ...
# 31269259  False            False    False                  True       False
# 31269260  False            False    False                  True       False
# 31269261  False            False    False                  True       False
# 31269262  False            False    False                  True       False
# 31269263  False            False    False                  True       False
#
# ...

# %%
df.replace("-",np.nan, inplace=True)

# %%
missing_data = df.isnull()

for column in headers:
    print(column)
    print(missing_data[column].value_counts())
    print('')
# Out:
# index
# index
# False    31269264
# Name: count, dtype: int64
#
# Login Timestamp
# Login Timestamp
# False    31269264
# Name: count, dtype: int64
#
# User ID
# User ID
# False    31269264
# Name: count, dtype: int64
#
# Round-Trip Time [ms]
# Round-Trip Time [ms]
# True     29993329
# False     1275935
# Name: count, dtype: int64
#
# IP Address
# IP Address
# False    31269264
# Name: count, dtype: int64
#
# Country
# Country
# False    31269264
# Name: count, dtype: int64
#
# Region
# Region
# False    17208474
# True     14060790
# Name: count, dtype: int64
#
# City
# City
# False    17356122
# True     13913142
# Name: count, dtype: int64
#
# ASN
# ASN
# False    31269264
# Name: count, dtype: int64
#
# User Agent String
# User Agent String
# False    31269264
# Name: count, dtype: int64
#
# Browser Name and Version
# Browser Name and Version
# False    31269264
# Name: count, dtype: int64
#
# OS Name and Version
# OS Name and Version
# False    31269264
# ...

# %%
df.head(10)
# Out:
#    index          Login Timestamp              User ID  Round-Trip Time [ms]  \
# 0      0  2020-02-03 12:43:30.772 -4324475583306591935                   NaN
# 1      1  2020-02-03 12:43:43.549 -4324475583306591935                   NaN
# 2      2  2020-02-03 12:43:55.873 -3284137479262433373                   NaN
# 3      3  2020-02-03 12:43:56.180 -4324475583306591935                   NaN
# 4      4  2020-02-03 12:43:59.396 -4618854071942621186                   NaN
# 5      5  2020-02-03 12:44:05.160 -4324475583306591935                   NaN
# 6      6  2020-02-03 12:44:07.893  7246533443898239661                   NaN
# 7      7  2020-02-03 12:44:12.799 -3243978724802435038                   NaN
# 8      8  2020-02-03 12:44:17.474  8076000552587369902                   NaN
# 9      9  2020-02-03 12:44:19.071 -3065936140549856249                   NaN
#
#         IP Address Country    Region       City     ASN  \
# 0      10.0.65.171      NO       NaN        NaN   29695
# ...

# %%
df.drop(columns=['Round-Trip Time [ms]'], inplace=True)
df.drop(columns=['Region'], inplace=True)
df.drop(columns=['City'], inplace=True)

# %% [markdown]
# LABEL ENCODING

# %%
from sklearn.preprocessing import LabelEncoder

# %%
label_encoder = LabelEncoder()

# %%
df ['Login Timestamp']= label_encoder.fit_transform(df["Login Timestamp"])
df ['IP Address']= label_encoder.fit_transform(df["IP Address"])
df ['Country']= label_encoder.fit_transform(df["Country"])
df ['User Agent String']= label_encoder.fit_transform(df["User Agent String"])
df ['Browser Name and Version']= label_encoder.fit_transform(df["Browser Name and Version"])
df ['OS Name and Version']= label_encoder.fit_transform(df["OS Name and Version"])
df ['Device Type']= label_encoder.fit_transform(df["Device Type"])
df ['Login Successful']= label_encoder.fit_transform(df["Login Successful"])
df ['Is Attack IP']= label_encoder.fit_transform(df["Is Attack IP"])
df ['Is Account Takeover']= label_encoder.fit_transform(df["Is Account Takeover"])

# %%
df.head(10)
# Out:
#    index  Login Timestamp              User ID  IP Address  Country     ASN  \
# 0      0                0 -4324475583306591935       55906      153   29695
# 1      1                1 -4324475583306591935     1382360       11   60117
# 2      2                2 -3284137479262433373     2747745      153   29695
# 3      3                3 -4324475583306591935      966173      211  393398
# 4      4                4 -4618854071942621186         215      211  398986
# 5      5                5 -4324475583306591935     1486043      211  393398
# 6      6                6  7246533443898239661     2514645      153   15659
# 7      7                7 -3243978724802435038      966200      211  393398
# 8      8                8  8076000552587369902       54928      153   29695
# 9      9                9 -3065936140549856249     3350964      153   29695
#
#    User Agent String  Browser Name and Version  OS Name and Version  \
# ...

# %%
df.value_counts(['Is Attack IP'])
# Out:
# Is Attack IP
# 0               28172287
# 1                3096977
# Name: count, dtype: int64

# %%
df.value_counts(['Login Successful'])
# Out:
# Login Successful
# 0                   18727822
# 1                   12541442
# Name: count, dtype: int64

# %%
df.value_counts(['Is Account Takeover'])
# Out:
# Is Account Takeover
# 0                      31269123
# 1                           141
# Name: count, dtype: int64

# %%
df.drop(columns=['Is Account Takeover'], inplace=True)
df.head(10)
# Out:
#    index  Login Timestamp              User ID  IP Address  Country     ASN  \
# 0      0                0 -4324475583306591935       55906      153   29695
# 1      1                1 -4324475583306591935     1382360       11   60117
# 2      2                2 -3284137479262433373     2747745      153   29695
# 3      3                3 -4324475583306591935      966173      211  393398
# 4      4                4 -4618854071942621186         215      211  398986
# 5      5                5 -4324475583306591935     1486043      211  393398
# 6      6                6  7246533443898239661     2514645      153   15659
# 7      7                7 -3243978724802435038      966200      211  393398
# 8      8                8  8076000552587369902       54928      153   29695
# 9      9                9 -3065936140549856249     3350964      153   29695
#
#    User Agent String  Browser Name and Version  OS Name and Version  \
# ...

# %%
from sklearn.preprocessing import StandardScaler

scl = StandardScaler()
X = df.iloc[:,2:3].values
X = scl.fit_transform(X)
df.iloc[:,2:3] = X

X = df.iloc[:,3:4].values
X = scl.fit_transform(X)
df.iloc[:,3:4] = X

X = df.iloc[:,4:5].values
X = scl.fit_transform(X)
df.iloc[:,4:5] = X

X = df.iloc[:,5:6].values
X = scl.fit_transform(X)
df.iloc[:,5:6] = X

X = df.iloc[:,6:7].values
X = scl.fit_transform(X)
df.iloc[:,6:7] = X

X = df.iloc[:,7:8].values
X = scl.fit_transform(X)
df.iloc[:,7:8] = X

X = df.iloc[:,8:9].values
X = scl.fit_transform(X)
df.iloc[:,8:9] = X

df.head(10)
# Out:
# C:\Users\Tejas\AppData\Local\Temp\ipykernel_13704\4028272140.py:6: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[-0.53174255 -0.53174255 -0.30128743 ... -0.53174255 -0.53174255
#  -0.42955911]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df.iloc[:,2:3] = X
# C:\Users\Tejas\AppData\Local\Temp\ipykernel_13704\4028272140.py:10: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[-1.29194805  0.00622627  1.34250158 ... -0.40113764 -1.12431774
#  -0.57922612]' has dtype incompatible with int32, please explicitly cast to a compatible dtype first.
#   df.iloc[:,3:4] = X
# ...

# %%
X = df.iloc[:,1:-1].values
Y = df.iloc[:,-1].values

# %%
plt.scatter(X[:100,1:2],Y[:100])

# %% [markdown]
# SPLIT and MODEL

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, random_state=42, stratify=Y)

# %%
len(X_train)
# Out:
# 25015411

# %%
len(X_test)
# Out:
# 6253853

# %%
len(Y_train)
# Out:
# 25015411

# %%
len(Y_test)
# Out:
# 6253853

# %%
import imblearn
from imblearn.under_sampling import RandomUnderSampler

# Instantiate the RandomUnderSampler
undersampler = RandomUnderSampler(random_state=4)

# Resample the training data
X_train_resampled, Y_train_resampled = undersampler.fit_resample(X_train, Y_train)
X_test_resampled, Y_test_resampled =undersampler.fit_resample(X_test, Y_test)

# %%
len(X_train_resampled)
# Out:
# 4955164

# %%
len(Y_train_resampled)
# Out:
# 4955164

# %%
Y_train_resampled.sum()
# Out:
# 2477582

# %%
len(X_test_resampled)
# Out:
# 1238790

# %%
len(Y_test_resampled)
# Out:
# 1238790

# %%
Y_test_resampled.sum()
# Out:
# 619395

# %%
plt.scatter(X_train[:100,1:2],Y_train[:100])

# %%
plt.scatter(X_train_resampled[:200,1:2],Y_train_resampled[:200])

# %%
plt.scatter(X_test[:100,1:2],Y_test[:100])

# %%
plt.scatter(X_test_resampled[:100,1:2],Y_test_resampled[:100])

# %%
from sklearn.linear_model import LogisticRegression

# %%
lg_model = LogisticRegression()
lg_model = lg_model.fit(X_train, Y_train)

# %%
from sklearn.metrics import classification_report,confusion_matrix
y_pred = lg_model.predict(X_test)

print(classification_report(Y_test, y_pred))
# Out:
# c:\Users\Tejas\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\metrics\_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# c:\Users\Tejas\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\metrics\_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
#               precision    recall  f1-score   support
#
#            0       0.90      1.00      0.95   5634458
#            1       0.00      0.00      0.00    619395
#
#     accuracy                           0.90   6253853
#    macro avg       0.45      0.50      0.47   6253853
# ...

# %%
confusion_matrix(Y_test,y_pred)
# Out:
# array([[5634458,       0],
#        [ 619395,       0]], dtype=int64)

# %%
y_pred = lg_model.predict_proba(X_test)
y_pred
# Out:
# array([[0.91667741, 0.08332259],
#        [0.75409022, 0.24590978],
#        [0.85155194, 0.14844806],
#        ...,
#        [0.7300718 , 0.2699282 ],
#        [0.96020138, 0.03979862],
#        [0.54094215, 0.45905785]])

# %%
lg_model = LogisticRegression()

# %%
lg_model = lg_model.fit(X_train_resampled, Y_train_resampled)

# %%
from sklearn.metrics import classification_report,confusion_matrix
y_pred_resampled = lg_model.predict(X_test_resampled)

print(classification_report(Y_test_resampled, y_pred_resampled))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.82      0.73      0.77    619395
#            1       0.75      0.84      0.79    619395
#
#     accuracy                           0.78   1238790
#    macro avg       0.78      0.78      0.78   1238790
# weighted avg       0.78      0.78      0.78   1238790

# %%
confusion_matrix(Y_test_resampled,y_pred_resampled)
# Out:
# array([[450713, 168682],
#        [101959, 517436]], dtype=int64)

# %%
from sklearn.ensemble import RandomForestClassifier

# Instantiate the Random Forest classifier
rf_model = RandomForestClassifier(random_state=42)

# Train the model
rf_model.fit(X_train_resampled, Y_train_resampled)

# Predict on the test set
y_pred_rf = rf_model.predict(X_test_resampled)

# Evaluate the model
print("Random Forest Classification Report:")
print(classification_report(Y_test_resampled, y_pred_rf))
# Out:
# Random Forest Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.99      1.00      1.00    619395
#            1       1.00      0.99      1.00    619395
#
#     accuracy                           1.00   1238790
#    macro avg       1.00      1.00      1.00   1238790
# weighted avg       1.00      1.00      1.00   1238790

# %%
confusion_matrix(Y_test_resampled,y_pred_rf)
# Out:
# array([[618339,   1056],
#        [  3798, 615597]], dtype=int64)

# %% [markdown]
# 99.608% ACCURACY

# %%
from sklearn.ensemble import GradientBoostingClassifier

# Instantiate the Gradient Boosting classifier
gb_model = GradientBoostingClassifier(random_state=42)

# Train the model
gb_model.fit(X_train_resampled, Y_train_resampled)

# Predict on the test set
y_pred_gb = gb_model.predict(X_test_resampled)

# Evaluate the model
print("Gradient Boosting Classification Report:")
print(classification_report(Y_test_resampled, y_pred_gb))
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[83], line 7
#       4 gb_model = GradientBoostingClassifier(random_state=42)
#       6 # Train the model
# ----> 7 gb_model.fit(X_train_resampled, Y_train_resampled)
#       9 # Predict on the test set
#      10 y_pred_gb = gb_model.predict(X_test_resampled)
#
# File c:\Users\Tejas\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py:1474, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1467     estimator._validate_params()
#    1469 with config_context(
#    1470     skip_parameter_validation=(
#    1471         prefer_skip_nested_validation or global_skip_validation
#    1472     )
#    1473 ):
# -> 1474     return fit_method(estimator, *args, **kwargs)
#
# ...
